# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
from scipy import stats
from sklearn.linear_model import LinearRegression

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #ADJUST the configuration of the plots we will create

# %%
df = pd.read_csv(r"C:\Users\HomePC\Downloads\movies.csv")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df['budget']= df['budget'].fillna(df['budget'].mean())

# %%
df['gross'] = df['gross'].fillna(df['gross'].mean())

# %%
df.isnull().sum()
# Out:
# name            0
# rating         77
# genre           0
# year            0
# released        2
# score           3
# votes           3
# director        0
# writer          3
# star            1
# country         3
# budget          0
# gross           0
# company        17
# runtime         4
# Y_predicted     0
# dtype: int64

# %%
# Let see if there is any missing data

# %%
#df.isnull()

for col in df.columns:
        missing = np.mean(df[col].isnull())
        print('{} - {}%'.format(col, missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data types of columns

df = df.fillna(value=0)
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df.dropna(subset = 'budget')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
df['company'].value_counts()

#df.drop_duplicates()
# Out:
# company
# Universal Pictures          377
# Warner Bros.                334
# Columbia Pictures           332
# Paramount Pictures          320
# Twentieth Century Fox       240
#                            ...
# Digital Image Associates      1
# Kopelson Entertainment        1
# Clavius Base                  1
# Tim Burton Productions        1
# PK 65 Films                   1
# Name: count, Length: 2386, dtype: int64

# %%
df.groupby('country')[['budget', 'gross']].mean()
# Out:
#                                       budget         gross
# country
# 0                               8.333333e+05  1.680000e+04
# Argentina                       9.250000e+05  1.703046e+07
# Aruba                           3.000000e+07  1.031992e+07
# Australia                       1.174946e+07  3.270553e+07
# Austria                         7.780000e+06  2.092008e+07
# Belgium                         1.351250e+07  5.060999e+06
# Brazil                          5.316667e+06  1.650788e+07
# Canada                          1.339474e+07  3.197522e+07
# Chile                           1.300000e+07  1.955851e+07
# China                           4.616000e+07  2.197357e+08
# Colombia                        3.000000e+06  1.259463e+07
# Czech Republic                  3.362500e+07  2.158306e+07
# Denmark                         6.306250e+06  1.204891e+07
# Federal Republic of Yugoslavia  7.000000e+06  2.612645e+05
# Finland                         4.600000e+07  1.691938e+08
# ...

# %%
#budget high correlation
#company high correlation

# %%
# scatter plot with budget vs gross

# %%
#sns.scatterplot(df, x = 'budget', y = 'gross')
#df.plot(kind = 'scatter', x='budget', y= 'gross', color = 'red')
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for film')
plt.show()

# %%
# plotting regression plot between budget vs gross

# %%
c = sns.regplot(df, x= 'budget', y='gross', color = 'blue', line_kws={"color":"red"})

# %%
# looking  for correlation

df[['budget','gross']].corr(method = 'pearson')
# Out:
#          budget    gross
# budget  1.00000  0.71127
# gross   0.71127  1.00000

# %%
corr_matrix = df[['budget','gross']].corr(method = 'pearson')
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix for Numeric features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# looking at company

# %%
df_numerized = df

for col_name in df_numerized:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1     5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3      286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000.0      1054     522
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18.0      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36.0       774    2615
# 7665  4717       0      6  2020       194    5.7       29.0      2061    2684
# 7666  2843       0      6  2020      2818    0.0        0.0      1184    1825
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
#
# ...

# %%
corr_matrix = df[['budget','gross','company']].corr(method = 'pearson')
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix for Numeric features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score     0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes     0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget    0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# gross     0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186012
# ...

# %%
## Fitting the regression model between gross and budget
X = df[['gross']]
y = df['budget']

# %%
lim = LinearRegression()
lim.fit(X, y)
lim.coef_
#lin.intercept_
# Out:
# array([0.15253797])

# %%
lim.intercept_
# Out:
# 23615563.102180228

# %%
Y_predict= lim.predict(X)
Y_predict
# Out:
# array([3.07846603e+07, 3.25928964e+07, 1.05738202e+08, ...,
#        3.55898762e+07, 3.55898762e+07, 3.55898762e+07])

# %%
df['Y_predicted'] = Y_predict

# %%
lim.score(X, Y)
# Out:
# 0.4770382479549652

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(Y, df['Y_predicted'])
# Out:
# 778668282064818.9

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime
# 0  1048       55  19000000   46998772     2320    146.0
# 1   328       56   4500000   58853106      732    104.0
# 2  1746       56  18000000  538375067     1541    124.0
# 3  2247       56   3500000   83453539     1813     88.0
# 4   411       56   6000000   39846344     1778     98.0

# %%
## To get the significance of correlation betwwen budget and gross

# %%
pearson_coef, p_value = stats.pearsonr(df['gross'], df['budget'])
pearson_coef, p_value
# Out:
# (0.7112703460962948, 0.0)

# %%
## To evaluate the model by residual plot

# %%
sns.residplot(df, x= df['budget'], y=df['gross'], color = 'b')
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
sns.distplot(df['budget'], hist = False, label = 'Fitted values')
# Out:
# C:\Users\HomePC\AppData\Local\Temp\ipykernel_12436\1343168921.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['budget'], hist = False, label = 'Fitted values')
# C:\Users\HomePC\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
